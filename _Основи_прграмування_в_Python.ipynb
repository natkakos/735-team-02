# %% [markdown]
# <a href="https://colab.research.google.com/github/natkakos/735-team-02/blob/main/_%D0%9E%D1%81%D0%BD%D0%BE%D0%B2%D0%B8_%D0%BF%D1%80%D0%B3%D1%80%D0%B0%D0%BC%D1%83%D0%B2%D0%B0%D0%BD%D0%BD%D1%8F_%D0%B2_Python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Python

# %% [markdown]
# ![Dizajn bez názvu.png](data:image/png;base64,...)

# %% [markdown]
# ![Rieši zložité problémy za menej času s menším počtom riadkov kódu (1).png](data:image/png;base64,...)

# %% [markdown]
# Ťahák: https://www.w3schools.com/python/default.asp

# %% [markdown]
# *У Python змінні створюються, коли ви присвоюєте їм значення:*

# %%
x = 15
y = "Hello, World!"

x
# Out:
# 15

# %%
print(x+100)
# Out:
# 115

# %% [markdown]
# *Правильні* назви змінних:

# %%
myvar = "John"
moje_meno = "John"
_my_var = "John"
mojeMeno = "Kika"
MYVAR = "John"
myvar2 = "John"

# %%
MYVAR
# Out:
# 'John'

# %% [markdown]
# Неправильні назви змінних:

# %%
myvar = "John"
myvar = "John"
&mojemeno = "John"
# Out:
#   File "<ipython-input-14-2e440c33075c>", line 3
#     &mojemeno = "John"
#     ^
# SyntaxError: invalid syntax

# %%
x = 5
y = "John"
print(type(x))
print(type(y))
# Out:
# <class 'int'>
# <class 'str'>

# %%
x = 555
y = 16
print(x - y)
# Out:
# 539

# %%
y
# Out:
# 'John'

# %%
import nltk

# %% [markdown]
# **Тип данних - string**

# %% [markdown]
# strings використовуються для зберігання тексту. Їх можна записувати в одинарних або подвійних лапках. Конкатенація кількох рядків виконується за допомогою оператора «+».

# %%
x = "Python"
y = "is"
z = "awesome"
print(x + y + z)
# Out:
# Pythonisawesome

# %%
x = 5
y = 1000
print(x + y)

# %%
meno = "Kristina"
priezvisko = 'Frolova'

cele_meno = meno + ' ' + priezvisko

print(meno + ' ' + priezvisko)
# Out:
# Kristina Frolova

# %%
cele_meno
# Out:
# 'Kristina Frolova'

# %%
len(cele_meno)
# Out:
# 16

# %% [markdown]
# Завантаження введення (програма очікує введення
# введення користувача)

# %%
print('Як вас звати?')

meno = input()

if len(meno) < 3:
  print('Помилка')
else:
  print('Усе гаразд')
  print('Привіт '+ meno +' :)')
# Out:
# Як вас звати?
# d
# Помилка

# %%
print('Як вас звати?')

meno = input()

if meno == 'boss':
  print('Hello dear', meno)
if len(meno) < 3:
  print('Помилка')
else:
  print('Усе гаразд')
  print('Привіт '+ meno +' :)')
# Out:
# Як вас звати?
# boss
# Hello dear boss
# Усе гаразд
# Привіт boss :)

# %% [markdown]
# Довжина рядка визначається функцією len().

# %%
print(len("a"))
print(len("Python"))
print(len("Reťazca"))
print(len("Reťazca v Pythone."))
# Out:
# 1
# 6
# 7
# 18

# %% [markdown]
# Отримайте літеру в позиції 1 (пам’ятайте, що перший символ знаходиться в позиції 0):

# %%
a = "hello, world!"
print(a[1])
print(a.upper())
print(a.lower())
print(a.title())
# Out:
# e
# HELLO, WORLD!
# hello, world!
# Hello, World!

# %%
print(len(a))
# Out:
# 13

# %%
print(a[0])
# Out:
# h

# %% [markdown]
# Boolean data type

# %%
print("kra" in "okraj")
print(";" in "python")
# Out:
# True
# False

# %%
a = "100"
print(100 == int(a))
# Out:
# True

# %%
meno = "Tata+"
if '+' in meno:
  print('помилка')
# Out:
# помилка

# %%
b = "Hello, World!"
print(b[2:5])
# Out:
# llo

# %% [markdown]
# дізнатися, чи цей текст (рядок) містить моє ім'я (kika) ...

# %%
'kik' == 'Kik'
# Out:
# False

# %%
txt = "Lorem Ipsum is simply dummy text of  printing and typesetting  industry. Lorem Ipsum has been the industry's standard dummy text ever since the 1500s, when an unknown printer took a galley of type and scrambled it to make a type specimen book. It has survived not only five centuries, but also the leap into electronic typesetting, remaining essentially unchanged. It was popularised in the 1960s with the release of Letraset sheets containing Lorem Ipsum passages, and more recently with desktop publishing software like Aldus PageMaker including versions of Lorem Ipsum."
if "kik" or "Kik"in txt:
  print("Nachádzam sa v texte.")
else:
  print("Nenachádzam sa v texte.")

# %%
txt = "Lorem Ipsum is simply dummy text of kik printing and typesetting  industry. Lorem Ipsum has been the industry's standard dummy text ever since the 1500s, when an unknown printer took a galley of type and scrambled it to make a type specimen book. It has survived not only five centuries, but also the leap into electronic typesetting, remaining essentially unchanged. It was popularised in the 1960s with the release of Letraset sheets containing Lorem Ipsum passages, and more recently with desktop publishing software like Aldus PageMaker including versions of Lorem Ipsum."
if "KIK" in txt.upper():
  print("Is in the text")
else:
  print("Not in the text")
# Out:
# Is in the text

# %%
'kik' in txt.upper()
# Out:
# False

# %% [markdown]
# python видасть вам помилку, якщо ви порушите вказаний відступ

# %%
if 5 > 2:
  print("Five is greater than two!") 
if 5 < 2:
  print("Five is greater than two!")
# Out:
# Five is greater than two!

# %% [markdown]
# ## Тип даних список (List)

# %% [markdown]
# Списки є типом контейнера для впорядкованих послідовностей елементів. Списки можна ініціалізувати (список людей на концерті)

# %%
moj_list = []

# %%
type(moj_list)
# Out:
# list

# %%
moj_list = ["Zebra ", "Žirafa", "Žeriav", "Tukan", "Leňochod"]

list2 = [1, 5, 7, 9, 3]

list3 = ["abc", 34, True, 40, "male", 50.3]

# %%
list2
# Out:
# [1, 5, 7, 9, 3]

# %% [markdown]
# Списки мають динамічний розмір - до них можна додавати елементи

# %%
moj_list.append("Hroch")
moj_list
# Out:
# ['Zebra ', 'Žirafa', 'Žeriav', 'Tukan', 'Leňochod', 'Hroch']

# %%
list2.append(10)

# %%
list2
# Out:
# [1, 5, 7, 9, 3, 10]

# %% [markdown]
# метод `insert()`
#
# Вставляє одне значення в поле перед вказаним індексом:
# `pole.insert(index, prvok)`
#
# Якщо індекс == 0, він вставить на самому початку, якщо індекс == довжина поля (але може бути більше), він додасть вказане значення в кінець поля (тобто фактично виконає append()).

# %%
pole = ['MArtina', 'Pala', 'Katka', 'Juraj', 'Peter', 'Paula']
pole.insert(2, 'Kika')

# %%
pole
# Out:
# ['MArtina', 'Pala', 'Kika', 'Katka', 'Juraj', 'Peter', 'Paula']

# %%
pole.insert(0, "ahoj")

# %%
pole
# Out:
# ['ahoj', 'MArtina', 'Pala', 'Kika', 'Katka', 'Juraj', 'Peter', 'Paula']

# %% [markdown]
# Маємо доступ до окремих елементів списку (індексація починається з 0)

# %%
pole[1]
# Out:
# 'MArtina'

# %% [markdown]
# Ми можемо отримати доступ до «фрагментів» списку за допомогою `my_list[ i : j ]`, де i — початок фрагмента (знову ж таки, індексація починається з 0), а j — кінець фрагмента. Наприклад:

# %%
moj_list[0:5]
# Out:
# ['Zebra ', 'Žirafa', 'Žeriav', 'Tukan', 'Leňochod']

# %%
moj_list[-2]
# Out:
# 'Tukan'

# %% [markdown]
# Пропущення другого індексу означає, що зріз має працювати до кінця списку

# %%
moj_list[3:]
# Out:
# ['Tukan', 'Leňochod']

# %% [markdown]
# Ми можемо перевірити, чи є елемент у списку, використовуючи `in`

# %%
print(moj_list)
# Out:
# ['Zebra ', 'Žirafa', 'Žeriav', 'Tukan', 'Leňochod']

# %%
"Zebra " in moj_list
# Out:
# True

# %%
for a in moj_list:
  print(a)
# Out:
# Zebra
# Žirafa
# Žeriav
# Tukan
# Leňochod

# %%
for animal in moj_list:
  if 'tuk' in animal.lower():
    print(animal, ' uraaa!')
# Out:
# Tukan  uraaa!

# %% [markdown]
# Метод `remove()`
#
# Цей метод спочатку знаходить перше (крайнє ліве) входження заданого значення в масиві, а потім відкидає цей елемент із масиву. Його форма:
#
# `pole.remove(hodnota)`

# %%
pole = ['a', 'b', 'c']
pole.remove('b')
pole
# Out:
# ['a', 'c']

# %% [markdown]
# замінюємо c на b - на другому місці поля вставляємо з індексом 1 вставляємо b

# %%
print(pole)
# Out:
# ['a', 'b']

# %%
pole[1] = 'aa'
pole
# Out:
# ['a', 'aa']

# %% [markdown]
# Метод `pop()`
#
# Він відкидає або останній елемент із масиву (якщо він викликається без параметрів), або елемент із вказаним індексом:
#
# `pole.pop()`
#
# `pole.pop(index)`

# %%
p = ['a', 'b', 'c']
p.pop(2)
p
# Out:
# ['a', 'b']

# %% [markdown]
# Довжину списку можна отримати за допомогою функції len

# %%
len(p)
# Out:
# 2

# %% [markdown]
# ЗАДАЧА
# 1. Дізнатися, скільки тварин у списку zoo_22
# 2. Дізнатись, чи є Лінивець(Lenochod) у списку zoo_22
# 3. Додайте до них Тигра до списку на 4 місце у списку
# 4. Замініть Лінивець(Lenochod) на панду
# 5. Додати до списку додавання Koala
# 6. Дізнатися довжину списку

# %%
zoo_22 = ["", "Zebra", "Žirafa", "Žeriav", "Tukan", "Leňochod", "Vráskavec ozrutný", "Ťava", "Slon", "Somár"]

# %%
len(zoo_22)
# Out:
# 10

# %%
zoo_22[3] = 'Tiger'

# %%
print(zoo_22)
# Out:
# ['', 'Zebra', 'Žirafa', 'Tiger', 'Tukan', 'Leňochod', 'Vráskavec ozrutný', 'Ťava', 'Slon', 'Somár']

# %%
"Leňochod" in zoo_22
# Out:
# True

# %%
element = 'Leňochod'
index_element = ''
for i, animal in enumerate(zoo_22):
  #print(i, animal)
  if animal == element:
    print(i)
    index_element = i
# Out:
# 5

# %%
zoo_22[index_element] = 'Super Panda'
zoo_22
# Out:
# ['',
#  'Zebra',
#  'Žirafa',
#  'Tiger',
#  'Tukan',
#  'Super Panda',
#  'Vráskavec ozrutný',
#  'Ťava',
#  'Slon',
#  'Somár']

# %%
element = 'Leňochod'
if "" in zoo_22:
  print(element , "є, усе гаразд!")
else:
  print(element , ' ' , 'Немає! Халепа!')

# %%
i=0
for zviera in zoo_22:
  #print(zviera)
  if zviera == "Tukan":
    print("tukan sa nachadza na", i, "mieste")
  i+=1

# %%
element = ''
for i, zviera in enumerate(zoo_22):
  #print(i, zviera)
  if zviera == element:
    print(element, " sa nachadza na", i, "mieste")

# %% [markdown]
# ##Podmienky

# %% [markdown]
# Дорівнює: `a == b`
#
# Не дорівнює: `a != b`
#
# Менше ніж: `a < b`
#
# Менше або дорівнює: `a <= b`
#
# Більше ніж: `a > b`
#
# Більше або дорівнює: `a >= b`

# %%
print("Задайте перше число")
a = int(input())
print("Задайте друге число")
b = int(input())
print("Задайте операцію")
operacia = input()
if operacia == "*":
  vysledok = a*b
elif operacia == "/":
  vysledok = a/b
elif operacia == "+":
  vysledok = a+b
elif operacia == "-":
  vysledok = a-b
else:
  vysledok = "сталась помилка"

print(vysledok)
# Out:
# Задайте перше число
# 4
# Задайте друге число
# 5
# Задайте операцію
# *
# 20

# %% [markdown]
# **ELIF**
#
# Слово elif означає "якщо попередні умови не відповідають дійсності, спробуйте цю умову".

# %%
a = 33
b = 32
if a > b:
  print("a більше b")
elif a < b:
  print("a менше b")
# Out:
# a більше b

# %% [markdown]
# **ELSE**
#
# Слово else фіксує все, що не фіксується попередніми умовами IF або ELIF.

# %%
a = 200
b = 33
if a > b:
  print("a більше b")
elif a < b:
  print("a менше b")
elif a==b:
  print("a і b рівні")

# %% [markdown]
# `and` - chceme, zistiť či platia viaceré podmienky naraz
#
# `or` - chceme, zistiť, či platí jedna alebo druhá podmienka
#
# and vráti hodnotu True, ak sú oba výroky pravdivé `x < 5 and x < 10`
#
# or Vráti hodnotu True, ak je jeden z výrokov pravdivý `x < 5 or x < 4`

# %%
veta = "Мене звати Kika."
if veta[0].isupper and "." in veta:
  print("Це оповідальне речення")
else:
  print("десь була помилка")

# %%
veta = "Мене звати Kika!"
if "!" in veta or "." in veta or "?" in veta:
  print("Речення закінчено правильно")
else:
  print("десь була помилка")

# %% [markdown]
# ## Цикли - Loops

# %% [markdown]
# **For loop**

# %%
moj_list = ["Zebra ", "Žirafa", "Žeriav", "Tukan", "Leňochod"]
poradie = 1
for zviera in moj_list:
  print(zviera, "знаходиться в Кошицькому зоопарку")
  print(poradie, ' ' + zviera)
  poradie+=1

# %%
for pismenko in "banana":
  print(pismenko)

# %%
for cislo in range(10):
  nasobok_3 = cislo*3
  print('cislo: ',cislo)
  print('nasobok_3: ',nasobok_3)
  print('--------')

# %% [markdown]
# **ЗАДАЧА**
#
# дано: список номерів - "ціни"
# потрібно отримати: все подорожчало на 2 євро

# %%
ceny = [5, 3, 4, 4.5, 3.8]
for cena in ceny:
  nova_cena = cena + 2
  print(nova_cena)

# %% [markdown]
# **While loop**

# %%
i = 0
while i < 5:
  print(i+1, moj_list[i])
  i += 1

# %%
moj_list[0:5]

# %% [markdown]
# **Задача**
#
# Гра - спробуй вгадати моє число

# %%
import random
  
# Generates a random number between
# a given positive range
hadane_cislo = random.randint(0, 100) #50
print("Skus uhadnut moje cislo")
tip = int(input())
i = 0
  while hadane_cislo != tip:
    if tip > hadane_cislo:
      print("Hadaj mensie.")
    elif tip < hadane_cislo:
      print('Hadaj vacsie.')

    print("Skus tipnut este raz")
    tip = int(input())   
    i+=1

  print("skvele, uhadla si na :)")

# %%
print("Random number between 0 and 100 is", hadane_cislo)

# %% [markdown]
# ## Функції

# %% [markdown]
# Щоб покращити читабельність коду, прийнято розбивати код на різні блоки, відповідальні за виконання певних дій: функцій. Функція приймає деякі вхідні дані та обробляє їх, щоб повернути деякі виходи.
#
# Іншими словами, якщо, наприклад, я знаю, що виконуватиму щось кілька разів, але з різними вхідними даними, я створюю одну загальну функцію і просто вставляю в неї числа.

# %%
import math

def mocnina(x):
  return x ** 2

def násobenie(a, b):
  return a * b

def prepona(a, b):
  c = math.sqrt(a**2 + b**2)
  return c

# Functions can be composed.
#mocnina(násobenie(3, 2))
prepona(a=1, b=11)
# Out:
# 11.045361017187261

# %%
a = input()
b = input()
prepona(int(a), int(b))
# Out:
# 3
# 3
# 4.242640687119285

# %%
mocnina(mocnina(2))

# %%
mocnina(násobenie(a=3, b=2))

# %% [markdown]
# Створіть функцію, у якій я вводжу ім’я та прізвище, і вона повертає електронний лист, створений таким чином: name.familiya@gmail.com

# %%
def create_email(name, surname):

  email = name + '.' + surname + '@gmail.com'

  email = email.lower()

  return email

# %%
print('Eneter name:')
n = input()
print('Enter surname')
s = input()
print('Enter you age')
a = input()
print('Your email: ')
create_email2(n, s, a)
# Out:
# Eneter name:
# tetiana
# Enter surname
# lysenko
# Enter you age
# 15
# Your email:
# 'tetiana вам ще рано мати мейл, спитайте у мами'

# %%
def create_email2(name, surname, age):
  
  a = int(age)

  if a > 18:

    email = name + '.' + surname + '@gmail.com'

    email = email.lower()
  else:
    email = name + ' вам ще рано мати мейл, спитайте у мами' 

  return email

# %%
create_email2('Tetiana', 'Lysenko', 2)
# Out:
# 'Tetiana вам ще рано мати мейл, спитайте у мами'
